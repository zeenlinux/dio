# %%
import pandas as pd

# %%
td = pd.read_csv("ocorrencia.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True)
td.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              52242               52242                INCIDENTE
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
# 4              45407               45407                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                 ****     2012-01-06
# 3     SÃO SEBASTIÃO            SP                 ****     2012-01-06
# 4          SÃO SEPÉ            RS                 ****     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 0        20:27:00                    0
# 1        13:44:00                    3
# ...

# %%
td.loc[1,'ocorrencia_cidade']
# Out:
# 'GUARULHOS'

# %%
td.loc[1:3]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                 ****     2012-01-06
# 3     SÃO SEBASTIÃO            SP                 ****     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 1        13:44:00                    3
# 2        13:00:00                    0
# 3        17:00:00                    0

# %%
td.loc[[10,40]]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              45332               45332                 ACIDENTE
# 40              45415               45415                 ACIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10            VIAMÃO            RS                 ****     2012-01-09
# 40    RIO DE JANEIRO            RJ                 ****     2012-01-30
#
#    ocorrencia_hora  total_recomendacoes
# 10        13:30:00                    0
# 40        13:55:00                    0

# %%
td.loc[:,'ocorrencia_cidade']
# Out:
# 0        PORTO ALEGRE
# 1           GUARULHOS
# 2              VIAMÃO
# 3       SÃO SEBASTIÃO
# 4            SÃO SEPÉ
#             ...
# 5162            JATAÍ
# 5163          MARACAÍ
# 5164    NOVO HAMBURGO
# 5165         CURITIBA
# 5166        PETROLINA
# Name: ocorrencia_cidade, Length: 5167, dtype: object

# %%
td.codigo_ocorrencia.is_unique
# Out:
# True

# %%
td.set_index('codigo_ocorrencia')
#inplace=True faz a modificação no dataframe
#para resetar o index td.reset_index(drop=True, inplace=True)
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 52242                           52242                INCIDENTE
# 45331                           45331                 ACIDENTE
# 45333                           45333                 ACIDENTE
# 45401                           45401                 ACIDENTE
# 45407                           45407                 ACIDENTE
# ...                               ...                      ...
# 80458                           80458                 ACIDENTE
# 80452                           80452                 ACIDENTE
# 80457                           80457          INCIDENTE GRAVE
# 80460                           80460                INCIDENTE
# 80467                           80467                INCIDENTE
#
#                   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 52242                  PORTO ALEGRE            RS                 SBPA
# ...

# %% [raw]
# td['total_recomendacoes_bkp'] =td.total_recomendacoes
# isso faria um bakup das linhas q eu pretendo fazer alteraçoes

# %% [raw]
# ocorrencia_uf **
# ocorrencia_aerodromo **** ***** #### ###!
# ocorrencia_hora NULL

# %%
td.replace(['**','****','*****','####','###!','NULL'], pd.NA, inplace=True)

# %%
td.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        1905
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
td.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        1905
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %% [raw]
# td.fillna(0, inplace=True) substitui todos os nulls por 0
# td.fillna(value={'total_recomendacoes':0}, inplace=True) substitui todos os nasa de totalrec para 0
